# %%
import pandas as pd

# %%
tabela = pd.read_csv("brasileirao.csv")

tabela.tail(10)
# Out:
#            Time  Pontos  Jogos  Vitórias  Empates  Derrotas  Gols Pró  \
# 10    São Paulo      53     38        14       11        13        40
# 11       Cuiabá      51     38        14        9        15        40
# 12  Corinthians      50     38        12       14        12        47
# 13     Cruzeiro      47     38        11       14        13        35
# 14        Vasco      45     38        12        9        17        41
# 15        Bahia      44     38        12        8        18        50
# 16       Santos      43     38        11       10        17        39
# 17        Goiás      38     38         9       11        18        36
# 18     Coritiba      30     38         8        6        24        41
# 19   América-MG      24     38         5        9        24        42
#
#     Gols Contra  Saldo de Gols   %
# 10           38              2  46
# 11           39              1  44
# 12           48             -1  43
# 13           32              3  41
# ...
